# %%
import salem
import shapely.geometry as shpg
import matplotlib.pyplot as plt
g, maps = salem.geogrid_simulator('/mnt/d/work/sunhh/data/run2/1/namelist.wps')
maps[0].set_shapefile(r"/mnt/d/work/sunhh/script/map/cn_shp/Province_9south/province_9south.shp")
fig, ax = plt.subplots()
p = shpg.point.Point([110, 35])
# maps[0].set_geometry(p, crs=g[0].proj, zorder=1, linewidth=1, marker='*', facecolor='red')
maps[0].set_geometry(p, crs=g[0].proj, zorder=1, linewidth=1,marker='',facecolor='red')

#‘lr’, ‘mr’ or ‘hr’ (low res, medium or high res) natural earth background img
maps[0].set_rgb(natural_earth='hr')
s = maps[0].visualize(title='WPS Domain')
fig.savefig("/mnt/d/work/sunhh/figure/run2/domain.png",dpi=600, bbox='tight')
# Out:
# /mnt/d/work/miniconda/envs/sunhh/lib/python3.9/site-packages/salem/graphics.py:1172: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(g.x, g.y, **kwargs)
# /tmp/ipykernel_1045/1647087194.py:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error in 3.6
#   fig.savefig("/mnt/d/work/sunhh/figure/run2/domain.png",dpi=600, bbox='tight')
